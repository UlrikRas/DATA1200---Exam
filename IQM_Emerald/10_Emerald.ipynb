# %%
import sys
import subprocess

# --- Check Python version ---
major, minor = sys.version_info[:2]

if not (major == 3 and minor == 12):
    print(f"❌ Python {major}.{minor} detected.")
    print("Please change the Colab runtime to **Python 3.12**:")
    print("Runtime → Change runtime type → Runtime version → 2025.10")
    raise SystemExit

print(f"✅ Python {major}.{minor} detected (OK).")

# --- Check pip version ---
pip_version_output = subprocess.check_output(["pip", "--version"]).decode()
pip_version = pip_version_output.split()[1]  # e.g. "25.0"

print(f"Detected pip version: {pip_version}")

if not pip_version.startswith("25"):
    print("❌ pip version is not 25.x. Installing pip 25...")
    # !pip install --upgrade pip==25.*
    print("✅ pip 25 installed.")
    print("Please RESTART the runtime now (Runtime → Restart session).")
else:
    print("✅ pip 25.x is already installed.")
# Out:
# ✅ Python 3.12 detected (OK).
# Detected pip version: 24.1.2
# ❌ pip version is not 25.x. Installing pip 25...
# Collecting pip==25.*
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 6.3 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.3
# ✅ pip 25 installed.
# Please RESTART the runtime now (Runtime → Restart session).

# %%
 install iqm-client with qrisp extras
# !pip install -U "iqm-client==33.0.5" "qrisp[iqm]"
# used for visualization
# !pip install matplotlib

from qrisp.interface import IQMBackend

# Set use_timeslot=True if you have booked a timeslot
quantum_computer = IQMBackend(
    api_token = input("IQM Resonance API token"),
    device_instance = "emerald",
    use_timeslot=False)
# Out:
# Requirement already satisfied: iqm-client==33.0.5 in /usr/local/lib/python3.12/dist-packages (33.0.5)
# Requirement already satisfied: qrisp[iqm] in /usr/local/lib/python3.12/dist-packages (0.8.2)
# Requirement already satisfied: numpy<3.0,>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from iqm-client==33.0.5) (2.0.2)
# Requirement already satisfied: packaging==24.1 in /usr/local/lib/python3.12/dist-packages (from iqm-client==33.0.5) (24.1)
# Requirement already satisfied: pydantic<3.0,>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from iqm-client==33.0.5) (2.13.4)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.12/dist-packages (from iqm-client==33.0.5) (2.32.3)
# Requirement already satisfied: iqm-pulse<13,>=12.7.5 in /usr/local/lib/python3.12/dist-packages (from iqm-client==33.0.5) (12.7.5)
# Requirement already satisfied: iqm-station-control-client<13,>=12.0.5 in /usr/local/lib/python3.12/dist-packages (from iqm-client==33.0.5) (12.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->iqm-client==33.0.5) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->iqm-client==33.0.5) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->iqm-client==33.0.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->iqm-client==33.0.5) (2026.4.22)
# Requirement already satisfied: iqm-data-definitions<3.0,>=2.18 in /usr/local/lib/python3.12/dist-packages (from iqm-pulse<13,>=12.7.5->iqm-client==33.0.5) (2.22)
# Requirement already satisfied: python-rapidjson==1.20 in /usr/local/lib/python3.12/dist-packages (from iqm-pulse<13,>=12.7.5->iqm-client==33.0.5) (1.20)
# Requirement already satisfied: jinja2<4,>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from iqm-pulse<13,>=12.7.5->iqm-client==33.0.5) (3.1.6)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from iqm-pulse<13,>=12.7.5->iqm-client==33.0.5) (1.16.3)
# Requirement already satisfied: scipy-stubs in /usr/local/lib/python3.12/dist-packages (from iqm-pulse<13,>=12.7.5->iqm-client==33.0.5) (1.17.1.4)
# Requirement already satisfied: protobuf<5.0,>=4.25.3 in /usr/local/lib/python3.12/dist-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulse<13,>=12.7.5->iqm-client==33.0.5) (4.25.9)
# Requirement already satisfied: types-protobuf in /usr/local/lib/python3.12/dist-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulse<13,>=12.7.5->iqm-client==33.0.5) (7.34.1.20260508)
# Requirement already satisfied: opentelemetry-exporter-otlp<2.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.27.0)
# Requirement already satisfied: grpcio<2.0,>=1.65.4 in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.80.0)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (6.0.3)
# Requirement already satisfied: types-requests in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (2.33.0.20260513)
# Requirement already satisfied: tqdm>=4.59.0 in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (4.67.3)
# Requirement already satisfied: types-tqdm in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (4.67.3.20260508)
# Requirement already satisfied: iqm-exa-common<28,>=27.4.5 in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (27.5.3)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio<2.0,>=1.65.4->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (4.15.0)
# Requirement already satisfied: python-dotenv<2,>=0.21.1 in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.5->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.2.2)
# Requirement already satisfied: ruamel-yaml<0.20,>=0.17.32 in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.5->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (0.19.1)
# Requirement already satisfied: six<2,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.5->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.17.0)
# Requirement already satisfied: types-six in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.5->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.17.0.20260408)
# Requirement already satisfied: xarray==2024.10.0 in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.5->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (2024.10.0)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from xarray==2024.10.0->iqm-exa-common<28,>=27.4.5->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (2.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4,>=3.1.6->iqm-pulse<13,>=12.7.5->iqm-client==33.0.5) (3.0.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.27.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.27.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.3.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.74.0)
# Requirement already satisfied: opentelemetry-api~=1.15 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk~=1.27.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (1.27.0)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (8.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (3.23.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk~=1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (0.48b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.9.2->iqm-client==33.0.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.9.2->iqm-client==33.0.5) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.9.2->iqm-client==33.0.5) (0.4.2)
# Requirement already satisfied: sympy<=1.13 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (1.13.0)
# Requirement already satisfied: qiskit>=0.44.0 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (2.1.2)
# Requirement already satisfied: matplotlib>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (3.10.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (0.60.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (3.6.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (0.3.8)
# Requirement already satisfied: flask<2.3.0 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (2.2.5)
# Requirement already satisfied: waitress in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (3.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (5.9.5)
# Requirement already satisfied: jax==0.7.1 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (0.7.1)
# Requirement already satisfied: jaxlib==0.7.1 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (0.7.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax==0.7.1->qrisp[iqm]) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax==0.7.1->qrisp[iqm]) (3.4.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from flask<2.3.0->qrisp[iqm]) (3.1.8)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.12/dist-packages (from flask<2.3.0->qrisp[iqm]) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from flask<2.3.0->qrisp[iqm]) (8.3.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy<=1.13->qrisp[iqm]) (1.3.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<28,>=27.4.5->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<28,>=27.4.5->iqm-station-control-client<13,>=12.0.5->iqm-client==33.0.5) (2026.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.44.0->qrisp[iqm]) (0.17.1)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.44.0->qrisp[iqm]) (5.7.0)
# Requirement already satisfied: qiskit-aer<0.18,>=0.13.1 in /usr/local/lib/python3.12/dist-packages (from iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.17.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->qrisp[iqm]) (0.43.0)
# Requirement already satisfied: optype<0.18,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from optype[numpy]<0.18,>=0.14.0->scipy-stubs->iqm-pulse<13,>=12.7.5->iqm-client==33.0.5) (0.17.0)
# Requirement already satisfied: numpy-typing-compat<20251207,>=20250818.1.25 in /usr/local/lib/python3.12/dist-packages (from optype[numpy]<0.18,>=0.14.0->scipy-stubs->iqm-pulse<13,>=12.7.5->iqm-client==33.0.5) (20251206.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# IQM Resonance API token+qq3UGPdpGSi+mvmuhlDJxVpfChjB4/UoT9sQVRLuPwBniWq68Z8ApYfMZknLsHE

# %% [markdown]
# After successfully installing the required packages and initializing the backend, you can submit the quantum circuit.

# %%
from qrisp import *
from matplotlib import pyplot as plt

#Kristian-Krets reprodusert på Emerald
qv = QuantumVariable(3)

x(qv[2])

h(qv[0])
h(qv[1])
h(qv[2])

x(qv[1])

mcx(qv[0:2], qv[2])

h(qv[2])

h(qv[0])

z(qv[0])

cx(qv[0],qv[1])

h(qv[0])

print(qv)
print(qv.qs)
# Out:
# {'101': 1.0}
# QuantumCircuit:
# ---------------
#       ┌───┐          ┌───┐┌───┐     ┌───┐
# qv.0: ┤ H ├───────■──┤ H ├┤ Z ├──■──┤ H ├
#       ├───┤┌───┐  │  └───┘└───┘┌─┴─┐└───┘
# qv.1: ┤ H ├┤ X ├──■────────────┤ X ├─────
#       ├───┤├───┤┌─┴─┐┌───┐     └───┘
# qv.2: ┤ X ├┤ H ├┤ X ├┤ H ├───────────────
#       └───┘└───┘└───┘└───┘
# Live QuantumVariables:
# ----------------------
# QuantumVariable qv

# %%
#Execute on the quantum computing backend
#Transpilation is taken care of automatically

result = qv.get_measurement(backend = quantum_computer)

#run1

#Print and plot the result
print(result)

plt.bar(result.keys(), result.values())
plt.xlabel('Measurement outcomes')
plt.ylabel('Probability')
plt.show()
# Out:
# Progress in queue:   0%|          | 0/1 [00:00<?, ?it/s]
# {'101': 0.628, '110': 0.133, '111': 0.068, '100': 0.057, '001': 0.036, '010': 0.035, '000': 0.022, '011': 0.021}

# %%
#Execute on the quantum computing backend
#Transpilation is taken care of automatically

result = qv.get_measurement(backend = quantum_computer)

#run2

#Print and plot the result
print(result)

plt.bar(result.keys(), result.values())
plt.xlabel('Measurement outcomes')
plt.ylabel('Probability')
plt.show()
# Out:
# {'101': 0.556, '111': 0.136, '011': 0.081, '100': 0.059, '010': 0.056, '001': 0.051, '110': 0.038, '000': 0.023}

# %%
#Execute on the quantum computing backend
#Transpilation is taken care of automatically

result = qv.get_measurement(backend = quantum_computer)

#run3

#Print and plot the result
print(result)

plt.bar(result.keys(), result.values())
plt.xlabel('Measurement outcomes')
plt.ylabel('Probability')
plt.show()
# Out:
# {'101': 0.635, '111': 0.174, '001': 0.046, '100': 0.041, '011': 0.04, '000': 0.026, '010': 0.019, '110': 0.019}

# %%
#Execute on the quantum computing backend
#Transpilation is taken care of automatically

result = qv.get_measurement(backend = quantum_computer)

#run4

#Print and plot the result
print(result)

plt.bar(result.keys(), result.values())
plt.xlabel('Measurement outcomes')
plt.ylabel('Probability')
plt.show()
# Out:
# {'101': 0.6, '100': 0.094, '001': 0.089, '011': 0.068, '111': 0.067, '000': 0.028, '010': 0.027, '110': 0.027}

# %%
#Execute on the quantum computing backend
#Transpilation is taken care of automatically

result = qv.get_measurement(backend = quantum_computer)

#run5

#Print and plot the result
print(result)

plt.bar(result.keys(), result.values())
plt.xlabel('Measurement outcomes')
plt.ylabel('Probability')
plt.show()
# Out:
# {'101': 0.566, '110': 0.133, '111': 0.097, '100': 0.069, '001': 0.043, '010': 0.04, '011': 0.03, '000': 0.022}
